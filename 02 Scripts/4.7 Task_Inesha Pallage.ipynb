# %%
# Importing Libraries

import pandas as pd
import numpy as py
import os

# %%
# Import ords_prods_merge Data set

ords_prods_merge =pd.read_pickle(r'C:\Users\inesh\Instacart Basket Analysis_01_02_2024\02 Data\Prepared Data\ords_prods_merged.pkl')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 16)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_from_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                   NaN         196                  1          0   both
# 1                  15.0         196                  1          1   both
# 2                  21.0         196                  1          1   both
# 3                  29.0         196                  1          1   both
# 4                  28.0         196                  1          1   both
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices merge_indicator
# ...

# %% [markdown]
# ####  create subset for first one million row set

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_from_last_order    product_id  \
# count       3.240486e+07          3.032876e+07  3.240486e+07
# mean        1.342515e+01          1.110408e+01  2.559866e+04
# std         4.246380e+00          8.779064e+00  1.408400e+04
# min         0.000000e+00          0.000000e+00  1.000000e+00
# ...

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# ### Creating price label column using if else statements

# %% [markdown]
# #### Use created Price_label column in df

# %%
# Define function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Apply function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\inesh\AppData\Local\Temp\ipykernel_11448\3581963753.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
##Apply function


df.loc[:, 'price_range'] = df.apply(price_label, axis=1)

# %% [markdown]
# #### Check values in price_label column

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# #### If-Statements with the loc() Function

# %% [markdown]
# #### Use If statement with loc() for ords_prods_merge entire dataframe

# %%
ords_prods_merge.loc[ords_prods_merge['prices']>15, 'price_range_loc'] ='High-range product'

# %%
ords_prods_merge.loc [(ords_prods_merge['prices' ]<=15) & (ords_prods_merge['prices']>5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low_range_product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low_range_product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# #### Most Order take place days

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# #### Create a new column to show the busyness of order day

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result #show the result of created loop
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# #### Combining loop result with ords_prods_merge dataframe

# %%
ords_prods_merge['busiest_day']=result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(['orders_day_of_week', 'busiest_day']).size().reset_index(name='count')
# Out:
#    orders_day_of_week     busiest_day    count
# 0                   0     Busiest day  6204182
# 1                   1  Regularly busy  5660230
# 2                   2  Regularly busy  4213830
# 3                   3  Regularly busy  3840534
# 4                   4      Least busy  3783802
# 5                   5  Regularly busy  4205791
# 6                   6  Regularly busy  4496490

# %% [markdown]
# # 4.7 Task

# %% [markdown]
# ### Q2: Create columns for two “Busiest days” (plural) & two Slowest days

# %% [markdown]
# #### Busiest days : 0 and 1  Slowest days : 3 and 4

# %%
busiest_or_slowest =[]
for days in ords_prods_merge["orders_day_of_week"]:
  if days == 0 or days==1 :
    busiest_or_slowest.append("Busiest days")
  elif days == 4 or days==3:
    busiest_or_slowest.append("Slowest days")
  else:
    busiest_or_slowest.append("Regular days")

# %%
ords_prods_merge['busiest_days']=busiest_or_slowest

# %% [markdown]
# ### Q3:Check the values of this new column for accuracy. Note any observations in markdown format

# %%
ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(['orders_day_of_week', 'busiest_day','busiest_days']).size().reset_index(name='count')
# Out:
#    orders_day_of_week     busiest_day  busiest_days    count
# 0                   0     Busiest day  Busiest days  6204182
# 1                   1  Regularly busy  Busiest days  5660230
# 2                   2  Regularly busy  Regular days  4213830
# 3                   3  Regularly busy  Slowest days  3840534
# 4                   4      Least busy  Slowest days  3783802
# 5                   5  Regularly busy  Regular days  4205791
# 6                   6  Regularly busy  Regular days  4496490

# %% [markdown]
# ### Q4: identify the busiest hours of the day & labeled “Most orders,” “Average orders,” and “Fewest orders.”  then Create a new column containing these labels called *“busiest_period_of_day."*

# %% [markdown]
# #### Check order_hour_of_day

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# #### Create empty list and for loop to generate list of “busiest_period_of_day.”

# %%
## most_orders_hours =  9 to 17   average_orders_hours = 8, 18, 19

busiest_hours = []


for value in ords_prods_merge['order_hour_of_day']:
    if 9 <= value <= 17:
        busiest_hours.append("Most_orders")
    elif value in [8, 18, 19]:
        busiest_hours.append("Average_orders")
    else:
        busiest_hours.append("Fewest_orders")

# %%
# replacing the name of  busiest hour 
ords_prods_merge['busiest_period_of_day'] = busiest_hours

# %% [markdown]
# ## Q5 Print the frequency for this new column

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most_orders       23205725
# Average_orders     4612925
# Fewest_orders      4586209
# Name: count, dtype: int64

# %%
ords_prods_merge.groupby(['order_hour_of_day', 'busiest_period_of_day']).size().reset_index(name='count')
# Out:
#     order_hour_of_day busiest_period_of_day    count
# 0                   0         Fewest_orders   218769
# 1                   1         Fewest_orders   115700
# 2                   2         Fewest_orders    69375
# 3                   3         Fewest_orders    51281
# 4                   4         Fewest_orders    53242
# 5                   5         Fewest_orders    87961
# 6                   6         Fewest_orders   290493
# 7                   7         Fewest_orders   891054
# 8                   8        Average_orders  1718118
# 9                   9           Most_orders  2454203
# 10                 10           Most_orders  2761760
# 11                 11           Most_orders  2736140
# 12                 12           Most_orders  2618532
# 13                 13           Most_orders  2660954
# 14                 14           Most_orders  2689136
# 15                 15           Most_orders  2662144
# 16                 16           Most_orders  2535202
# ...

# %% [markdown]
# ## Q7: Export dataframe as a pickle file in “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(r'C:\Users\inesh\Instacart Basket Analysis_01_02_2024\02 Data\Prepared Data\ords_prods_merge_busiest_days_hours_updated.pkl')
